# %%
# ipython settings
# %load_ext autoreload
# %autoreload 2
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # 3. Synthetic experiments with Symbolic Pursuit

# %% [markdown]
# In this notebook, we shall reproduce one of the experiments from Section 6.1 of the paper.
# The idea is to start with a linear pseudo black-box for which the importance vector is known unambiguously and see which interpretability methods identifies this vector the most precisely. Let us start by the useful imports.

# %%
from symbolic_pursuit.models import SymbolicRegressor  # our symbolic model class
from sklearn.metrics import mean_squared_error # we are going to assess the quality of the model based on the generalization MSE
from sympy import init_printing # We use sympy to display mathematical expresssions 
import numpy as np # we use numpy to deal with arrays
import lime 
import lime.lime_tabular
init_printing()

# %% [markdown]
# We now define a linear pseudo black-box $f$ defined on a 3 dimensional feature space.
#
# $$ f(x_1,x_2,x_3)= x_1 + 2 \cdot x_2 + 3 \cdot x_3$$
#
# The importance vector associated to this model is trivially given by $\beta = (1,2,3)$ In this case, we shall keep it unnormalised, unlike in the main paper as we deal with few examples. Let us translate this in Python.

# %%
def f(X):
    return X[:, 0]+2*X[:,1]+3*X[:,2]

dim_X = 3

# %% [markdown]
# Now draw uniformly 100 test points  that we will feed to a *LIME* explainer <cite data-cite="2480681/WCEBQ7N9"></cite> and to train a Symbolic model.

# %%
n_pts = 100
X = np.random.uniform(0, 1, (n_pts, dim_X))

# %% [markdown]
# Now we draw 10 test ponits $x_{test} \equiv U([0,1]^3)$ that we are going to use in order to evaluate the perfomances of both explainers on unseen data.

# %%
n_test = 10
X_test = np.random.uniform(0, 1, (n_test, dim_X))

# %% [markdown]
# Since LIME produces importance vectors with entries in the form $(feature \ domain , importance)$ for each feature appearing in decreasing order of importance, we implement a function which identifies the feature from the first entry of the tuple and who sorts the importances in the form $(importance(x_1), importance(x_2), importance(x_3))$.

# %%
def order_weights(exp_list):
    ordered_weights = [0 for _ in range(dim_X)]
    for tup in exp_list:
        feature_id = int(tup[0].split('x_')[1][0])
        ordered_weights[feature_id-1] = tup[1]    
    return ordered_weights

# %% [markdown]
# We are now ready to extract the feature importance for our 10 test points as predicted by the LIME explainer :

# %%
lime_weight_list = []
explainer = lime.lime_tabular.LimeTabularExplainer(X, 
                                                   feature_names=["x_"+str(k) for k in range(1,dim_X+1)], 
                                                   class_names=['f'], 
                                                   verbose=True,
                                                   mode='regression')

for i in range(n_test):
    exp = explainer.explain_instance(X_test[i], f, num_features=dim_X)
    lime_weight_list.append(order_weights(exp.as_list()))  
                            
print(lime_weight_list)
# Out:
# Intercept 2.518993737302847
# Prediction_local [4.14817253]
# Right: 4.226696537551317
# Intercept 2.8540201524204534
# Prediction_local [3.0931134]
# Right: 2.725825616264876
# Intercept 3.5702520640094746
# Prediction_local [0.94054708]
# Right: 0.6719364136365406
# Intercept 2.4473897973068617
# Prediction_local [4.34197968]
# Right: 4.722531273983431
# Intercept 3.5781060771322766
# Prediction_local [0.97683103]
# Right: 1.2248527125692195
# Intercept 2.594500233172748
# Prediction_local [3.91449442]
# Right: 3.4924839956770235
# Intercept 2.5673817939755015
# Prediction_local [3.98953684]
# Right: 4.0846610125992
# Intercept 2.6702454213099442
# Prediction_local [3.68317199]
# Right: 3.6817672604216267
# Intercept 3.176176578789607
# Prediction_local [2.14577448]
# Right: 1.9829800773838895
# Intercept 3.4944840077548243
# Prediction_local [1.23087745]
# Right: 1.1348510092446296
# [[0.22270481896593872, 0.9595850735001481, 0.4468888992161167], [-0.17858606402367871, 0.9486206656448822, -0.5309413501852186], [-0.19893300275331566, -0.9977106789490469, -1.4330613071802736], [0.49388360550409877, 0.9270489737328079, 0.47365730440615555], [-0.15367268479969762, -0.9616047687692152, -1.4859975917947599], [-0.5344176912437139, 0.35598905608481196, 1.4984228190289626], [0.1942068968816597, -0.3000155308576475, 1.5279636750185417], [0.18961410049720895, 0.32686958110035913, 0.4964428891936233], [-0.18901433681739965, -0.32560529332668564, -0.5157824735546542], [0.14628464768510832, -0.9566322392878779, -1.4532589639991453]]

# %% [markdown]
# As we can see from the last output, which is the list of predicted importance vectors, LIME seems to produce a big variety of importance vectors. This is suprising for a global linear model. We also note that the relative importance seem inconsistent with the true importance vector $\beta$ defined above. Let us now train a Symbolic model for $f$ based on our training set.

# %%
symbolic_model = SymbolicRegressor(maxiter=10,
                 eps=1.0e-4)
symbolic_model.fit(f, X)
# Out:
# Model created with the following hyperparameters :
#  loss_tol=0.001
#  ratio_tol=0.9
#  maxiter=10
#  eps=0.0001
#  random_seed=42
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Now working on term number  1 .
# ====================================================================================================
# Now working on hyperparameter tree number  1 .
# Warning: NaN result encountered.
#          Current function value: inf
#          Iterations: 0
#          Function evaluations: 8
#          Gradient evaluations: 1
# ====================================================================================================
# Now working on hyperparameter tree number  2 .
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-501ce3bf42ee> in <module>
#       2 symbolic_model = SymbolicRegressor(maxiter=10,
#       3                  eps=1.0e-4)
# ----> 4 symbolic_model.fit(f, X)
#
# /media/pi/MyPassport/GraduateApplications/CAMAppication/Symbolic-Pursuit/symbolic_pursuit/models.py in fit(self, f, X)
#     226                 theta_g0, g_order = h_dic['hyper_' + str(k + 1)]
#     227                 theta_0 = np.concatenate((theta_g0, v0, [w0]))
# --> 228                 new_meijer_g, new_v, new_w, new_loss = self.tune_new_term(X, g_order, theta_0)
#     229                 new_loss_list.append(new_loss)
#     230                 new_terms_list.append([new_meijer_g, new_v, new_w])
#
# /media/pi/MyPassport/GraduateApplications/CAMAppication/Symbolic-Pursuit/symbolic_pursuit/models.py in tune_new_term(self, X, g_order, theta_0)
#     194             return loss_
#     195
# --> 196         new_theta, new_loss = self.optimize_CG(loss, theta_0)
#     197         new_theta_meijer, new_v, new_w = split_theta(new_theta)
#     198         new_meijerg = MeijerG(theta=new_theta_meijer, order=g_order)
#
# /media/pi/MyPassport/GraduateApplications/CAMAppication/Symbolic-Pursuit/symbolic_pursuit/models.py in optimize_CG(self, loss, theta_0)
#      83         # Encodes the parameters of the optimal parameters of an additional term inside theta_opt
#      84         opt = minimize(loss, theta_0, method='CG',
# ---> 85                        options={'disp': self.verbosity, 'maxiter': self.maxiter})
#      86         theta_opt = opt.x
#      87         loss_ = opt.fun
#
# ~/miniconda/envs/id/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     600         return _minimize_powell(fun, x0, args, callback, **options)
#     601     elif meth == 'cg':
# --> 602         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     603     elif meth == 'bfgs':
#     604         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#
# ~/miniconda/envs/id/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_cg(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1309     else:
#    1310         grad_calls, myfprime = wrap_function(fprime, args)
# -> 1311     gfk = myfprime(x0)
#    1312     k = 0
#    1313     xk = x0
#
# ~/miniconda/envs/id/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/miniconda/envs/id/lib/python3.7/site-packages/scipy/optimize/optimize.py in approx_fprime(xk, f, epsilon, *args)
#     763
#     764     """
# --> 765     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     766
#     767
#
# ~/miniconda/envs/id/lib/python3.7/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     695         ei[k] = 1.0
#     696         d = epsilon * ei
# --> 697         df = (f(*((xk + d,) + args)) - f0) / d[k]
#     698         if not np.isscalar(df):
#     699             try:
#
# ~/miniconda/envs/id/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /media/pi/MyPassport/GraduateApplications/CAMAppication/Symbolic-Pursuit/symbolic_pursuit/models.py in loss(theta)
#     188             meijer_g_ = MeijerG(theta=theta_g, order=g_order)
#     189             Y = w_ * meijer_g_.evaluate(ReLU(np.matmul(X, v_)
# --> 190                                              / (np.sqrt(self.dim_x) * np.linalg.norm(v_))))
#     191
#     192             loss_ = np.mean((Y - residual_list) ** 2)
#
# /media/pi/MyPassport/GraduateApplications/CAMAppication/Symbolic-Pursuit/pysymbolic/models/special_functions.py in evaluate(self, X)
#     143
#     144             evaluater_  = evaluators_[self.evaluation_mode]
# --> 145             Y           = np.array([evaluater_(X[k]) for k in range(len(X))])
#     146
#     147         return np.real(Y)
#
# /media/pi/MyPassport/GraduateApplications/CAMAppication/Symbolic-Pursuit/pysymbolic/models/special_functions.py in <listcomp>(.0)
#     143
#     144             evaluater_  = evaluators_[self.evaluation_mode]
# --> 145             Y           = np.array([evaluater_(X[k]) for k in range(len(X))])
#     146
#     147         return np.real(Y)
#
# <lambdifygenerated-28> in _lambdifygenerated(x)
#       1 def _lambdifygenerated(x):
# ----> 2     return ((x - 0.5)**15*(.304453122393709328614046318439060279311556080579521492759909200814737511216172640585131602905174951103633*hyper((-1.49011611938477e-8,), (0.999999985098839, 0.999999985098839), 1.) - .63601075798218527506926457718740886861773650069583637894976022409609446095684071688117235786930126705262*hyper((-1.49011611938477e-8,), (0.999999985098839, 0.999999985098839), 1.) + .7554814573716495265571728738890240320568477760572515608530537260954030879513330743000810837445816520801*hyper((-1.49011611938477e-8,), (0.999999985098839, 0.999999985098839), 1.) - .049209646595043624824122480671641848601023199315283272485054288676265896248707222123458433276477977327*hyper((-1.49011611938477e-8,), (0.999999985098839, 0.999999985098839), 1.) + .839714718123698388694417522146082964442654638749805362776860828926727002910446144836760976324862391014*hyper((-1.49011611938477e-8,), (0.999999985098839, 0.999999985098839), 1.99999999999999999739791478603478936176753700828032791112350571130106350231885519682547137445559789072929783089166002807602240889810019619333840653900717108763135913773841976413203737113243245605317255997788263362245731599 ...
#
# NameError: name 'hyper' is not defined

# %% [markdown]
# We now ask our symbolic model to predict the importance vectors for each test point.

# %%
symbolic_weight_list = [] 
for k in range(n_test):
    symbolic_weight_list.append(symbolic_model.get_feature_importance(X_test[k]))

# %%
print(symbolic_weight_list)
# Out:
# [[1.00000967565438, 1.99996722397121, 2.99995979598524], [0.999997435291419, 1.99994274376093, 2.99992307549896], [0.999980231686409, 1.99990833727565, 2.99987146553088], [1.00002582096255, 1.99999951390738, 3.00000823111490], [1.00007349722083, 2.00009486441546, 3.00015125754257], [1.00002883992770, 2.00000555171050, 3.00001728786171], [1.00004417751007, 2.00003622622911, 3.00006329985375], [0.999990374307830, 1.99992862209122, 2.99990189289581], [0.999975889221782, 1.99989965252934, 2.99985843835078], [0.999978882316061, 1.99990563859181, 2.99986741748627]]

# %% [markdown]
# As we can see, our results appear to be always consistent and very close to the true importance vector $\beta$.

# %% [markdown]
# ## References<div class="cite2c-biblio"></div>

# %% [markdown]
# <div class="cite2c-biblio"></div>
